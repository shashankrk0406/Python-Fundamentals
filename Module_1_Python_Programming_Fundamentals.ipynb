# %% [markdown]
# <a href="https://colab.research.google.com/github/shashankrk0406/Python-Fundamentals/blob/main/Module_1_Python_Programming_Fundamentals.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
length = 11
width = 5
area = length * width
print("The area of the rectangle is:",area)
# Out:
# The area of the rectangle is: 55

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
grade = 'B'

if grade == 'A':
  print("Excellent Work!")
else:
  print("Keep studying and you'll improve!")
# Out:
# Keep studying and you'll improve!

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
age = 18
if age >= 18:
  print("You are eligible to vote.")
else:
  print("You are not eligible to vote")
# Out:
# You are eligible to vote.

# %%
discount_rate = 15  # % discount
original_price = 75
final_price = original_price - ((discount_rate/100) * original_price)
print("The final price after discount is: $",final_price)
# Out:
# The final price after discount is: $ 63.75
